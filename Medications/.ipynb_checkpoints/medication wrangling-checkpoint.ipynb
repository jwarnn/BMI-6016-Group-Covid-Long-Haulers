# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Import patient IDs that have 14 day covid diagnosis COVID diagnosis

# %%
df_PID = pd.read_csv(r'/Volumes/KY/cleaning_project/chunks/Covid_patients.csv')
PID = df_PID['patient_id'].tolist()
print(PID[:10])
# Out:
# ['4aa5ad8abce18968c9416141e0c269c94749ce4e', '59dc70bb529e13a54774bfb6cf0b1bb737d8484c', '1f8556940cb0e878f1941528ada6b2613a3aeedb', '39ff8680fcb048c4b1e1090db191d719eedfdc06', '407e1bb13bcb727daf26a9e91ebebfd48bbeaa75', '3aeff13ce402ae1b8ddd87f361bafa523f3c8969', 'c54b5741f9b4293f8b391b0db9948aa7cf0bbe21', '4090b84010612fc157347eea6da7dbc774a51bfb', 'c85f36bf6029303a4819ca2172e296b4a6ea4745', '286d92ae7da5b346f4d92abec9fdcc5970edb72f']

# %% [markdown]
# Import chunked dataset

# %%
df_chunk = pd.read_csv(r'/Volumes/KY/cleaning_project/chunks/chunk1.csv')
print('prePID shape:',df_chunk.shape)
# Out:
# /Users/kevinyang/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# prePID shape: (10000000, 9)

# %% [markdown]
# Trim chunk by imported 14 day covid patient IDs

# %%
df = df_chunk[df_chunk['patient_id'].isin(PID)]
print('postPID shape:',df.shape)
# Out:
# postPID shape: (853439, 9)

# %% [markdown]
# Trimming unnecessary data

# %%
# Remove rows with Unknown value
df = df[df.ne('Unknown').all(axis=1)]

#drop encoutner_id 
df = df.drop("encounter_id", axis = 1)

#Drop trinetx column
df = df.drop("derived_by_TriNetX", axis = 1)

#Drop NaN values
df = df.dropna()

#Drop duplicate rows
df = df.drop_duplicates()

# %%
df.head
# Out:
# <bound method NDFrame.head of                                        patient_id code_system   code  \
# 13732    4aa5ad8abce18968c9416141e0c269c94749ce4e      RxNorm   6387
# 13736    4aa5ad8abce18968c9416141e0c269c94749ce4e      RxNorm   6387
# 13740    4aa5ad8abce18968c9416141e0c269c94749ce4e      RxNorm   6387
# 13744    4aa5ad8abce18968c9416141e0c269c94749ce4e      RxNorm   6387
# 13754    4aa5ad8abce18968c9416141e0c269c94749ce4e      RxNorm   6387
# ...                                           ...         ...    ...
# 9962360  6cadf2e830984d6540a1a48effc4f6a4c5d1b600      RxNorm   6932
# 9962361  6cadf2e830984d6540a1a48effc4f6a4c5d1b600      RxNorm  36387
# 9962364  6cadf2e830984d6540a1a48effc4f6a4c5d1b600      RxNorm  82003
# 9962365  6cadf2e830984d6540a1a48effc4f6a4c5d1b600      RxNorm  36387
# 9962368  6cadf2e830984d6540a1a48effc4f6a4c5d1b600      RxNorm  82003
#
#          start_date               route     brand  strength
# ...

# %% [markdown]
# Get values of recurrence for medications

# %%
meds = df['code'].value_counts()
meds
# Out:
# 9863      3470
# 161       2394
# 8591      1597
# 435       1198
# 1897       892
#           ...
# 1359         1
# 29787        1
# 40114        1
# 9671         1
# 141626       1
# Name: code, Length: 1218, dtype: int64

# %% [markdown]
# Read in 1 chunk to estimate size

# %%
DF = pd.read_csv(r'/Volumes/KY/cleaning_project/chunks/chunk1.csv')
DF.shape
# Out:
# /Users/kevinyang/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (10000000, 9)

# %% [markdown]
# 10**7 rows in 1 chunk out of 88
#
# At most 8.8*10**8 rows

# %% [markdown]
# Split entire medication zip file into multiple dataframes

# %%
df1 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',nrows=100000000)
df2 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,100000000), nrows=100000000)
df3 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,200000000), nrows=100000000)
df4 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,300000000), nrows=100000000)

print('prePID shape:',df4.shape)
# Out:
# prePID shape: (100000000, 9)

# %%
df5 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,400000000), nrows=100000000)
df6 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,500000000), nrows=100000000)
df7 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,600000000), nrows=100000000)
df8 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,700000000), nrows=100000000)
df9 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,800000000))

print('prePID shape:',df9.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-27903204247c> in <module>
#       1 df5 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,400000000), nrows=100000000)
#       2 df6 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,500000000), nrows=100000000)
# ----> 3 df7 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,600000000), nrows=100000000)
#       4 df8 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,700000000), nrows=100000000)
#       5 df9 = pd.read_csv(r'/Volumes/KY/cleaning_project/medication.zip',skiprows=range(1,800000000))
#
# ...

# %% [markdown]
# Trim the dataframes for unnecessary information

# %%
#Remove duplicate rows
df1 = df1.drop_duplicates()

#Drop NaN values
df1 = df1.dropna()

# Remove rows with Unknown value
df = df[df.ne('Unknown').all(axis=1)]

#Drop encounter id column
df1 = df1.drop(columns=['encounter_id'])

#Drop TriNetX column
df1 = df1.drop(columns=['derived_by_TriNetX'])

# %% [markdown]
# Trim by 14 day patient ID

# %%
print('prePID shape:',df1.shape)
df1_14 = df1[df1['patient_id'].isin(PID)]
print('postPID shape:',df1_14.shape)

# %%
meds1 = df1['code'].value_counts()

meds1_14 = df1_14['code'].value_counts()

print('medication precovid:', meds1)

print('medication 14 day post covid:', meds1_14)
